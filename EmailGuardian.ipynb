# %% [markdown]
# ***Email Guardian: Spam vs. Ham Classifier ***🚀📧

# %%
import os
import io
import numpy
import pandas as pd
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from google.colab import drive

drive.mount('/content/gdrive')

def readFiles(path):
    for root, dirnames, filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)

            inBody = False
            lines = []
            with io.open(path, 'r', encoding='latin1') as f:
                for line in f:
                    if inBody:
                        lines.append(line)
                    elif line == '\n':
                        inBody = True
            message = '\n'.join(lines)
            yield path, message

def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message, 'class': classification})
        index.append(filename)

    return DataFrame(rows, index=index)

data = DataFrame({'message': [], 'class': []})

data = pd.concat([data, dataFrameFromDirectory("/content/gdrive/My Drive/spam", "spam")])
data = pd.concat([data, dataFrameFromDirectory("/content/gdrive/My Drive/ham", "ham")])
data.head()
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data['message'].values)

classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)
# Out:
# Mounted at /content/gdrive
#                                                                                               message  \
# /content/gdrive/My Drive/spam/00003.2ee33bc6eac...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# /content/gdrive/My Drive/spam/00011.61816b9ad16...  Cellular Phone Accessories All At Below Wholes...
# /content/gdrive/My Drive/spam/00007.d8521faf753...  Help wanted.  We are a 14 year old fortune 500...
# /content/gdrive/My Drive/spam/00012.381e4f51291...  <table width="600" border="20" align="center" ...
# /content/gdrive/My Drive/spam/00010.445affef4c7...  Dear ricardo1 ,\n\n\n\n<html>\n\n<body>\n\n<ce...
#
#                                                    class
# /content/gdrive/My Drive/spam/00003.2ee33bc6eac...  spam
# /content/gdrive/My Drive/spam/00011.61816b9ad16...  spam
# /content/gdrive/My Drive/spam/00007.d8521faf753...  spam
# /content/gdrive/My Drive/spam/00012.381e4f51291...  spam
# ...

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data['message'].values)

classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)
# Out:
# MultinomialNB()

# %%
examples =[input("Enter the email:")]
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
print("it is a ",predictions[0])
# Out:
# Enter the email:Reminder: Team meeting tomorrow at 10 AM. Please be on time.
# it is a  ham
